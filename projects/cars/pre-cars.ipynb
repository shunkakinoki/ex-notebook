# %%
import scipy.io
import numpy as np
import pandas as pd

data = scipy.io.loadmat("/notebooks/data/cars/cars_annos.mat")
train_data = scipy.io.loadmat("/notebooks/data/cars/devkit/cars_train_annos.mat")
meta_data = scipy.io.loadmat("/notebooks/data/cars/devkit/cars_meta.mat")

# %%
train_len = len(train_data['annotations'][0])
train_len
# Out:
# 8144

# %%
class_int = train_data['annotations'][0][0]['class']
class_int = int(class_int)
class_int
# Out:
# 14

# %%
class_fname = train_data['annotations'][0][0]['fname']
class_fname = str(class_fname)[2:-2]
class_fname
# Out:
# '00001.jpg'

# %%
class_len = len(meta_data['class_names'][0])
class_len
# Out:
# 196

# %%
class_list = []
for name in meta_data['class_names'][0]:
    name = str(name)
    name = name[2:-2]
    class_list.append(name)

# %%
class_dict = {}

# %%
for i, name in enumerate(class_list):
    class_dict[i+1] = name

# %%
train_df = pd.DataFrame(columns=['image_id', 'attributes'], index=range(train_len))

# %%
for i in range(train_len):
    class_fname = train_data['annotations'][0][i]['fname']
    class_fname = str(class_fname)[2:-2]
    
    class_int = train_data['annotations'][0][i]['class']
    class_int = int(class_int)
    class_name = class_dict[class_int]
    class_name = class_name.replace(' ', '_')

    train_df.loc[i].image_id = class_fname
    train_df.loc[i].attributes = class_name

# %% [raw]
# for i in range(train_len):
#     class_fname = train_data['annotations'][0][i]['fname']
#     class_fname = str(class_fname)[2:-2]
#
#     class_int = train_data['annotations'][0][i]['class']
#     class_int = int(class_int)
#     if class_int == 1:
#         print("its one")
#     if class_int == 0:
#         print("its ZERO")

# %%
train_df
# Out:
#        image_id                                       attributes
# 0     00001.jpg                              Audi_TTS_Coupe_2012
# 1     00002.jpg                              Acura_TL_Sedan_2012
# 2     00003.jpg                       Dodge_Dakota_Club_Cab_2007
# 3     00004.jpg                 Hyundai_Sonata_Hybrid_Sedan_2012
# 4     00005.jpg              Ford_F-450_Super_Duty_Crew_Cab_2012
# 5     00006.jpg                       Geo_Metro_Convertible_1993
# 6     00007.jpg                           Dodge_Journey_SUV_2012
# 7     00008.jpg                         Dodge_Charger_Sedan_2012
# 8     00009.jpg                     Mitsubishi_Lancer_Sedan_2012
# 9     00010.jpg                      Chevrolet_Traverse_SUV_2012
# 10    00011.jpg                          Buick_Verano_Sedan_2012
# 11    00012.jpg                          Toyota_Sequoia_SUV_2012
# 12    00013.jpg                       Hyundai_Elantra_Sedan_2007
# 13    00014.jpg                       Dodge_Caravan_Minivan_1997
# 14    00015.jpg                         Volvo_C30_Hatchback_2012
# 15    00016.jpg                         Plymouth_Neon_Coupe_1999
# 16    00017.jpg                              Audi_TTS_Coupe_2012
# 17    00018.jpg                      Chevrolet_Malibu_Sedan_2007
# 18    00019.jpg                 Volkswagen_Beetle_Hatchback_2012
# 19    00020.jpg  Chevrolet_Corvette_Ron_Fellows_Edition_Z06_2007
# 20    00021.jpg                          Chrysler_300_SRT-8_2010
# 21    00022.jpg                          BMW_M6_Convertible_2010
# 22    00023.jpg                        GMC_Yukon_Hybrid_SUV_2012
# 23    00024.jpg                       Nissan_Juke_Hatchback_2012
# 24    00025.jpg                             Volvo_240_Sedan_1993
# 25    00026.jpg                 Hyundai_Sonata_Hybrid_Sedan_2012
# 26    00027.jpg                            Suzuki_SX4_Sedan_2012
# 27    00028.jpg              Dodge_Ram_Pickup_3500_Crew_Cab_2010
# 28    00029.jpg                             Spyker_C8_Coupe_2009
# 29    00030.jpg                             Volvo_240_Sedan_1993
# ...         ...                                              ...
# 8114  08115.jpg                       McLaren_MP4-12C_Coupe_2012
# 8115  08116.jpg                Mercedes-Benz_SL-Class_Coupe_2009
# 8116  08117.jpg        Chevrolet_Silverado_1500_Regular_Cab_2012
# 8117  08118.jpg                                  BMW_X5_SUV_2007
# 8118  08119.jpg               Chevrolet_Malibu_Hybrid_Sedan_2010
# 8119  08120.jpg                          Honda_Accord_Coupe_2012
# 8120  08121.jpg                    Lamborghini_Diablo_Coupe_2001
# 8121  08122.jpg                            Cadillac_SRX_SUV_2012
# 8122  08123.jpg                          Scion_xD_Hatchback_2012
# 8123  08124.jpg                        Bentley_Arnage_Sedan_2009
# 8124  08125.jpg              Chevrolet_Corvette_Convertible_2012
# 8125  08126.jpg                           Ford_Fiesta_Sedan_2012
# 8126  08127.jpg                             Acura_TSX_Sedan_2012
# 8127  08128.jpg                               Ford_GT_Coupe_2006
# 8128  08129.jpg                   Bugatti_Veyron_16.4_Coupe_2009
# 8129  08130.jpg                   Bugatti_Veyron_16.4_Coupe_2009
# 8130  08131.jpg                              GMC_Savana_Van_2012
# 8131  08132.jpg                    Lamborghini_Diablo_Coupe_2001
# 8132  08133.jpg                              Acura_TL_Sedan_2012
# 8133  08134.jpg                         HUMMER_H3T_Crew_Cab_2010
# 8134  08135.jpg                       Dodge_Caravan_Minivan_1997
# 8135  08136.jpg                          Toyota_Camry_Sedan_2012
# 8136  08137.jpg                              Audi_100_Sedan_1994
# 8137  08138.jpg                          Suzuki_Aerio_Sedan_2007
# 8138  08139.jpg                        Toyota_Corolla_Sedan_2012
# 8139  08140.jpg           Chrysler_Town_and_Country_Minivan_2012
# 8140  08141.jpg                    smart_fortwo_Convertible_2012
# 8141  08142.jpg                Mercedes-Benz_SL-Class_Coupe_2009
# 8142  08143.jpg                               Ford_GT_Coupe_2006
# 8143  08144.jpg                              Audi_100_Sedan_1994
#
# [8144 rows x 2 columns]

# %%
train_df.to_csv('/notebooks/data/cars/train.csv', index_label=False, index=False)

# %%
train_df.to_csv('cars/train.csv', index_label=False, index=False)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.insert(0, "/notebooks/")
from fastai.imports import *

# %%
PATH = "/notebooks/data/cars/"
IMG_PATH = "/notebooks/data/cars/cars_train/"
sz=224

# %%
img = plt.imread(f'{IMG_PATH}00009.jpg')
plt.imshow(img);

# %%
train_csv = f'/notebooks/notebook/projects/cars/train.csv'
train_df = pd.read_csv(train_csv, encoding='utf-8')

# %%
train_df
# Out:
#        image_id                                       attributes
# 0     00001.jpg                              Audi_TTS_Coupe_2012
# 1     00002.jpg                              Acura_TL_Sedan_2012
# 2     00003.jpg                       Dodge_Dakota_Club_Cab_2007
# 3     00004.jpg                 Hyundai_Sonata_Hybrid_Sedan_2012
# 4     00005.jpg              Ford_F-450_Super_Duty_Crew_Cab_2012
# 5     00006.jpg                       Geo_Metro_Convertible_1993
# 6     00007.jpg                           Dodge_Journey_SUV_2012
# 7     00008.jpg                         Dodge_Charger_Sedan_2012
# 8     00009.jpg                     Mitsubishi_Lancer_Sedan_2012
